# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import sklearn as sk
from bertopic import BERTopic
import nltk
import nltk.corpus
from gensim.models import Word2Vec
import os

# %%
# get words from the text corpus

from nltk.corpus import PlaintextCorpusReader
wordlists = PlaintextCorpusReader('da/processed', '.*')

da_words = []

for file in wordlists.fileids():
        da_words.append(wordlists.words(file))

# %%
# get the rosetta data

data_raw = pd.read_excel("rosetta_data_inputs_2023.xls")
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
# Get main columns and filter rows without headings
data = data_raw[["Overskrift", "Beskrivelse"]]
data = data[data['Overskrift'].notna()]

# %%
# remove danish words and prep data for use

def only_english(text):
       return " ".join(w for w in nltk.wordpunct_tokenize(text) if w.lower() not in da_words and w.isalpha())

# combine heading and description
title_strings = data['Overskrift'].astype('str')
description_strings = data['Beskrivelse'].astype('str')
docs = title_strings + " \n\n" + description_strings

docs.apply(only_english)
# Out:
# 1       Combi material design Use a combination of mat...
# 2       Sterilization with UV light UVC light can be u...
# 3       seperation by oscillation Protein powder is in...
# 4       high pressure expose the product to high enoug...
# 5       Filtration push the product through a membrane...
#                               ...
# 5487    Weather resistance inspired by arctic animals ...
# 5488    Multiple options for power generation To provi...
# 5489    Adaptable To increase the maneuverability of t...
# 5490    Weather balloon for communication relay Satell...
# 5491    Adaptable sensor image frequency and resolutio...
# Length: 5339, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Remove stopwords after documents are assigned to topics
# Allows the transformer model to get the full context of the 
# data, while removing stopwords that are noise in the topics
vectorizer_model = CountVectorizer(stop_words="english")

# Define and train the model
topic_model = BERTopic(nr_topics=20, vectorizer_model=vectorizer_model)
topics, probs = topic_model.fit_transform(docs)

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                     Name  \
# 0      -1   1103             -1_use_water_nan_temperature
# 1       0    927                0_nan_robot_blinds_ground
# 2       1    685            1_weeds_toilet_protein_detect
# 3       2    495             2_cups_people_plastic_glands
# 4       3    373               3_tank_fish_tanks_chickens
# 5       4    345             4_heat_exchanger_wind_pumice
# 6       5    198                  5_pizza_oven_buns_bread
# 7       6    174           6_berries_pulp_potatoes_starch
# 8       7    160             7_chair_wheels_table_elderly
# 9       8    153  8_esg_employees_employee_sustainability
# 10      9    143               9_board_gypsum_boards_wall
# 11     10    121              10_window_windows_old_frame
# 12     11    113         11_bed_matress_pressure_mattress
# 13     12     85                12_hearing_aids_aid_alarm
# 14     13     74              13_shot_alcohol_shots_stent
# 15     14     58                14_bricks_lego_model_good
# 16     15     53        15_fashion_trends_popular_changes
# 17     16     51         16_color_change_lighting_surface
# 18     17     17               17_ved_beskyttelse_brud_en
# 19     18     11       18_bearing_efficiency_noise_sensor
#
#                                        Representation  \
# 0   [use, water, nan, temperature, heat, using, en...
# 1   [nan, robot, blinds, ground, robots, explosive...
# 2   [weeds, toilet, protein, detect, use, kill, po...
# 3   [cups, people, plastic, glands, cup, packaging...
# 4   [tank, fish, tanks, chickens, random, tires, m...
# 5   [heat, exchanger, wind, pumice, turbine, turbi...
# 6   [pizza, oven, buns, bread, rolls, random, diff...
# 7   [berries, pulp, potatoes, starch, potato, prod...
# 8   [chair, wheels, table, elderly, chairs, citize...
# 9   [esg, employees, employee, sustainability, ini...
# 10  [board, gypsum, boards, wall, screws, walls, s...
# 11  [window, windows, old, frame, frames, glass, g...
# 12  [bed, matress, pressure, mattress, sores, pati...
# 13  [hearing, aids, aid, alarm, sound, noise, nois...
# 14  [shot, alcohol, shots, stent, pill, asma, nan,...
# 15  [bricks, lego, model, good, idea, build, brain...
# 16  [fashion, trends, popular, changes, future, wa...
# 17  [color, change, lighting, surface, colors, bri...
# 18  [ved, beskyttelse, brud, en, stronger, og, bro...
# 19  [bearing, efficiency, noise, sensor, maintenan...
#
#                                   Representative_Docs
# 0   [Control the water temperature \n\nHeating/coo...
# 1   [Use micro-robots \n\nnan, people \n\nnan, Win...
# 2   [Piezoelectric sensors \n\nPiezoelectric senso...
# 3   [A triangle shaped cup made of grassseeds pres...
# 4   [flywheels on tank \n\nIn theory, it's possibl...
# 5   [Monitor conditions  \n\nMonitor conditions to...
# 6   [Big pizza oven \n\nMake the pizza oven bigger...
# 7   [Take berries home \n\nInstead of cutting stra...
# 8   [Assumption Future (No care workers) - Fully a...
# 9   [Physical Event Planner Platform (PEPP) \n\nA ...
# 10  [Gypsum board is incased with a metal frame \n...
# 11  [Big window made of old smaller windows  \n\nT...
# 12  [Matress with inbuild system making depression...
# 13  [Waterproof hearing aids \n\nIf the hearing ai...
# 14  [asma spray/ alcohol doser \n\nInstead of buyi...
# 15  [Generate current due to mechanical stress \n\...
# 16  [Study cultural influences on fashion \n\nStud...
# 17  [Thermo- and hydrochromic lego bricks \n\nReve...
# 18  [Anti-gravity \n\nEn teknologi som modarbejder...
# 19  [Monitoring bearing efficiency via noise  \n\n...

# %%
# set up Word2Vec embeddings

w2v = Word2Vec(docs, window=5, workers=4, min_count=3)

# %%
# do PCA

from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca_result = pca.fit_transform(w2v.wv.vectors)

# %%
import seaborn as sns

sns.scatterplot(data=pca_result, x=0, y=1)
plt.title("Transformed data")
plt.xlabel("First Eigenvector")
plt.ylabel("Second Eigenvector")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 3
#       1 import seaborn as sns
# ----> 3 sns.scatterplot(data=pca_result, x=0, y=1)
#       4 plt.title("Transformed data")
#       5 plt.xlabel("First Eigenvector")
#
# File /opt/miniconda3/envs/rosetta/lib/python3.11/site-packages/seaborn/relational.py:615, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     612     **kwargs
#     613 ):
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#     618         legend=legend
#     619     )
#     621     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     622     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File /opt/miniconda3/envs/rosetta/lib/python3.11/site-packages/seaborn/relational.py:396, in _ScatterPlotter.__init__(self, data, variables, legend)
#     387 def __init__(self, *, data=None, variables={}, legend=None):
#     388
#     389     # TODO this is messy, we want the mapping to be agnostic about
#     390     # the kind of plot to draw, but for the time being we need to set
#     391     # this information so the SizeMapping can use it
#     392     self._default_size_range = (
#     393         np.r_[.5, 2] * np.square(mpl.rcParams["lines.markersize"])
#     394     )
# --> 396     super().__init__(data=data, variables=variables)
#     398     self.legend = legend
#
# File /opt/miniconda3/envs/rosetta/lib/python3.11/site-packages/seaborn/_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File /opt/miniconda3/envs/rosetta/lib/python3.11/site-packages/seaborn/_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File /opt/miniconda3/envs/rosetta/lib/python3.11/site-packages/seaborn/_core/data.py:57, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
# ---> 57     data = handle_data_source(data)
#      58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#
# File /opt/miniconda3/envs/rosetta/lib/python3.11/site-packages/seaborn/_core/data.py:278, in handle_data_source(data)
#     276 elif data is not None and not isinstance(data, Mapping):
#     277     err = f"Data source must be a DataFrame or Mapping, not {type(data)!r}."
# --> 278     raise TypeError(err)
#     280 return data
#
# TypeError: Data source must be a DataFrame or Mapping, not <class 'numpy.ndarray'>.
